# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('dataset/boston_train.csv')

if 'ID' in df.columns: df = df.drop(columns=['ID'])

print(df.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 3  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 4  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  394.63   2.94  33.4
# 3  396.90   5.33  36.2
# 4  395.60  12.43  22.9

# %%
X_simple = df[['rm']].values
Y_simple = df[['medv']].values

plt.figure(figsize = (10,6))
plt.scatter(X_simple, Y_simple, alpha = 0.5)
plt.xlabel('rooms')
plt.ylabel('median price')
plt.grid(True, alpha=0.3)
plt.show()

# %%
print(df.describe().T[['mean', 'std', 'min', 'max']])
corrs = df.corr()['medv'].sort_values(ascending=False)
# Out:
#                mean         std        min       max
# ID       250.951952  147.859438    1.00000  506.0000
# crim       3.360341    7.352272    0.00632   73.5341
# zn        10.689189   22.674762    0.00000  100.0000
# indus     11.293483    6.998123    0.74000   27.7400
# chas       0.060060    0.237956    0.00000    1.0000
# nox        0.557144    0.114955    0.38500    0.8710
# rm         6.265619    0.703952    3.56100    8.7250
# age       68.226426   28.133344    6.00000  100.0000
# dis        3.709934    1.981123    1.12960   10.7103
# rad        9.633634    8.742174    1.00000   24.0000
# tax      409.279279  170.841988  188.00000  711.0000
# ptratio   18.448048    2.151821   12.60000   21.2000
# black    359.466096   86.584567    3.50000  396.9000
# lstat     12.515435    7.067781    1.73000   37.9700
# medv      22.768769    9.173468    5.00000   50.0000
